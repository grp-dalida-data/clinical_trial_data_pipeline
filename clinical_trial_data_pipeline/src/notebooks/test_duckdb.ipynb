# %%
import duckdb

# Define the path to the DuckDB file
db_path = '../data/clinical_trial_data.duckdb'

# Connect to the DuckDB file
conn = duckdb.connect(database=db_path)

# %%
# Query to list all tables
tables_query = "SHOW TABLES;"
tables = conn.execute(tables_query).fetchall()

# %%
# Define the table name you want to view
table_name = 'clinical_trial_data.filtered_studies'

# Execute a query to select all data from the table

query = f"PRAGMA database_list;"
result_df = conn.execute(query).fetchdf()

result_df['file']
# Out:
# 0    /Users/glenn/Documents/Exam/clinical_trial_dat...
# Name: file, dtype: object

# %%
# Define the table name you want to view
table_name = 'clinical_trial_data.filtered_studies'

# Execute a query to select all data from the table

query = f"DESCRIBE;"
result_df = conn.execute(query).fetchdf()

display(result_df)
# Out:
#                database                                schema  \
# 0   clinical_trial_data       data_clinical_trial_data_duckdb
# 1   clinical_trial_data       data_clinical_trial_data_duckdb
# 2   clinical_trial_data       data_clinical_trial_data_duckdb
# 3   clinical_trial_data       data_clinical_trial_data_duckdb
# 4   clinical_trial_data       data_clinical_trial_data_duckdb
# 5   clinical_trial_data       data_clinical_trial_data_duckdb
# 6   clinical_trial_data       data_clinical_trial_data_duckdb
# 7   clinical_trial_data  main_data_clinical_trial_data_duckdb
# 8   clinical_trial_data  main_data_clinical_trial_data_duckdb
# 9   clinical_trial_data  main_data_clinical_trial_data_duckdb
# 10  clinical_trial_data  main_data_clinical_trial_data_duckdb
# 11  clinical_trial_data  main_data_clinical_trial_data_duckdb
#
#                            name  \
# 0                    _dlt_loads
# 1           _dlt_pipeline_state
# 2                  _dlt_version
# 3              filtered_studies
# 4    filtered_studies__std_ages
# 5                       studies
# 6             studies__std_ages
# 7                    _dlt_loads
# 8           _dlt_pipeline_state
# 9                  _dlt_version
# 10          criteria_embeddings
# 11  custom_eligibility_criteria
#
#                                          column_names  \
# 0   [load_id, schema_name, status, inserted_at, sc...
# 1   [version, engine_version, pipeline_name, state...
# 2   [version, engine_version, inserted_at, schema_...
# 3   [nct_id, brief_title, acronym, overall_status,...
# 4     [value, _dlt_id, _dlt_parent_id, _dlt_list_idx]
# 5   [nct_id, brief_title, acronym, overall_status,...
# 6     [value, _dlt_id, _dlt_parent_id, _dlt_list_idx]
# 7   [load_id, schema_name, status, inserted_at, sc...
# 8   [version, engine_version, pipeline_name, state...
# 9   [version, engine_version, inserted_at, schema_...
# 10  [nct_id, brief_title, _dlt_load_id, _dlt_id, c...
# 11             [nct_id, brief_title, custom_criteria]
#
#                                          column_types  temporary
# 0   [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 1   [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 2   [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 3   [VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, ...      False
# 4                 [VARCHAR, VARCHAR, VARCHAR, BIGINT]      False
# 5   [VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, ...      False
# 6                 [VARCHAR, VARCHAR, VARCHAR, BIGINT]      False
# 7   [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 8   [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 9   [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 10      [VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR]      False
# 11                        [VARCHAR, VARCHAR, VARCHAR]      False

# %%
# Define the table name you want to view
table_name = 'clinical_trial_data.filtered_studies'

# Execute a query to select all data from the table

query = f"select * from main_data_clinical_trial_data_duckdb.criteria_embeddings;"
result_df = conn.execute(query).fetchdf()

display(result_df)
# Out:
#            nct_id                                        brief_title  \
# 0     NCT00072579  Sargramostim in Treating Patients With Chronic...
# 1     NCT00517179  Effect of Vardenafil on Blood Pressure in Pati...
# 2     NCT00812279  Investigate the Exposure to Selected Smoke Con...
# 3     NCT03878979  Preoperative Immune Checkpoint Inhibitor for P...
# 4     NCT04175379  The Effect of Permissive Hypercapnia on Oxygen...
# ...           ...                                                ...
# 4995  NCT01942902  A Comparative Study to Evaluate the Accuracy a...
# 4996  NCT00059202  Trial of High-dose Urso in Primary Sclerosing ...
# 4997  NCT02993302  Effects Of Oral Alfacalcidol On Maturation Of ...
# 4998  NCT00892502  Can Treatment With Bismuth Reduce Toxicity to ...
# 4999  NCT03170102  Building Capacity of OT Students to Address Ch...
#
#            _dlt_load_id         _dlt_id  \
# 0     1717972452.674242  j6yXX+0uQ4P8nQ
# 1     1717972452.674242  Pk7cSqE2DQ47hQ
# 2     1717972452.674242  UvrMNxj6ZOF10Q
# 3     1717972452.674242  wfgcQeJ8JKFZTw
# 4     1717972452.674242  p2bRYuuVx3LtjQ
# ...                 ...             ...
# 4995  1717972452.674242  tY+PomUE/Y0djg
# 4996  1717972452.674242  NOKN8Ap5Dzo3tw
# 4997  1717972452.674242  aQXW6+lw+fyRxQ
# 4998  1717972452.674242  nsZyq4sXNvb/Cw
# 4999  1717972452.674242  1gXO5xvqBt70Kg
#
#                                     criteria_embeddings
# 0     [-0.022854430601000786, 0.041770048439502716, ...
# 1     [0.011931512504816055, -0.04966897889971733, -...
# 2     [0.0012886746553704143, 0.02954927459359169, -...
# 3     [0.012103209272027016, 0.016129404306411743, -...
# 4     [0.061142269521951675, 0.034537576138973236, -...
# ...                                                 ...
# 4995  [-0.01735011115670204, 0.007894070819020271, -...
# 4996  [0.03214489296078682, -0.0880466029047966, -0....
# 4997  [-0.006661745719611645, 0.04200444743037224, -...
# 4998  [0.029126830399036407, 0.003005458042025566, -...
# 4999  [0.014706503599882126, 0.030444519594311714, 0...
#
# [5000 rows x 5 columns]

# %%
result_df.head()
# Out:
#         nct_id                                        brief_title  \
# 0  NCT05900479  Multi-site, Longitudinal Trial Evaluating the ...
# 1  NCT06221579  An Intergenerational, Cognitively Enriched Int...
# 2  NCT04081779  Survivorship Care Plans and Telehealth Educati...
# 3  NCT05523479  The Maximizing Extubation Outcomes Through Edu...
# 4  NCT03820479  A Study to Investigate Quality of Recovery up ...
#
#        acronym           overall_status  start_date  \
# 0      Unknown  ENROLLING_BY_INVITATION  2023-09-15
# 1  MCI-project  ENROLLING_BY_INVITATION  2023-09-13
# 2      Unknown  ENROLLING_BY_INVITATION  2020-02-19
# 3       METEOR  ENROLLING_BY_INVITATION  2023-03-01
# 4      Unknown  ENROLLING_BY_INVITATION  2019-02-11
#
#                                           conditions  \
# 0  Stress Disorders, Post-Traumatic, Combat Stres...
# 1                          Mild Cognitive Impairment
# 2  Breast Carcinoma, Colorectal Carcinoma, Lung C...
# 3       Acute Respiratory Failure, Airway Extubation
# 4                                Quality of Recovery
#
#                                        interventions  \
# 0                                   PTSD Service Dog
# 1  No intervention, interviews with MCI patients ...
# 2  Survivorship Care Plan, Educational Interventi...
# 3  Traditional online education, Interprofessiona...
# 4                                           Protocol
#
#                     locations primary_completion_date study_first_post_date  \
# 0      Tucson - United States                 2028-08            2023-06-12
# 1             Ghent - Belgium              2024-12-31            2024-01-24
# 2     Seattle - United States              2025-06-30            2019-09-09
# 3  Pittsburgh - United States                 2025-11            2022-08-31
# 4          Stockholm - Sweden              2024-02-28            2019-01-29
#
#    ...                               eligibility_criteria     sex minimum_age  \
# 0  ...  Inclusion Criteria:\n\n* Applied for and appro...     ALL    18 Years
# 1  ...  Inclusion criteria:\n\n1. MCI Diagnosis: Indiv...     ALL      0 Year
# 2  ...  Inclusion Criteria:\n\n* Cancer survivors who ...     ALL    18 Years
# 3  ...  Inclusion Criteria:\n\n* All adults treated wi...     ALL    18 Years
# 4  ...  Inclusion Criteria:\n\n* ASA class 1-2\n\nExcl...  FEMALE    18 Years
#
#   maximum_age normalized_minimum_age normalized_maximum_age diseases  \
# 0   120 Years                   18.0                  120.0
# 1   120 Years                    0.0                  120.0        s
# 2   120 Years                   18.0                  120.0     skin
# 3   120 Years                   18.0                  120.0
# 4    75 Years                   18.0                   75.0
#
#    medications       _dlt_load_id         _dlt_id
# 0               1717962172.820203  JVQ+Tt3/yEzAsg
# 1               1717962172.820203  zXvvYj+ahoWQVA
# 2    tamoxifen  1717962172.820203  LeLQoTIMg4J27w
# 3               1717962172.820203  sDzKPnaaI4U6Rw
# 4               1717962172.820203  A6vYvbU0xxtqDg
#
# [5 rows x 23 columns]

# %%
result_df.columns
# Out:
# Index(['nct_id', 'brief_title', 'acronym', 'overall_status', 'start_date',
#        'conditions', 'interventions', 'locations', 'primary_completion_date',
#        'study_first_post_date', 'last_update_post_date', 'study_type',
#        'phases', 'eligibility_criteria', 'sex', 'minimum_age', 'maximum_age',
#        'normalized_minimum_age', 'normalized_maximum_age', 'diseases',
#        'medications', '_dlt_load_id', '_dlt_id'],
#       dtype='object')

# %%
result_df[0:4]['conditions'].to_list()
# Out:
# ['Stress Disorders, Post-Traumatic, Combat Stress Disorders, Animal-Human Bonding',
#  'Mild Cognitive Impairment',
#  'Breast Carcinoma, Colorectal Carcinoma, Lung Carcinoma, Lymphoma, Prostate Carcinoma',
#  'Acute Respiratory Failure, Airway Extubation']

# %%
result_df['medications']
# Out:
# 0
# 1
# 2              tamoxifen
# 3
# 4
# 5
# 6                    uva
# 7
# 8
# 9
# 10
# 11
# 12
# 13             Xultophy®
# 14    levodopa/carbidopa
# 15
# 16
# 17
# 18          lenalidomide
# 19              steroids
# 20
# 21
# 22
# 23               opioids
# 24
# 25           Alemtuzumab
# 26            budesonide
# 27               Duodopa
# 28
# 29
# 30              steroids
# 31
# 32
# 33
# 34
# 35
# 36        hydrocortisone
# 37                 VIGIV
# 38             Milrinone
# 39
# 40        anti-androgens
# 41
# 42
# 43
# 44
# 45                    PC
# 46
# 47                    GH
# 48          anti-biotics
# 49
# 50
# 51           TheraSphere
# 52
# 53
# Name: medications, dtype: object

# %%
from transformers import pipeline as hf_pipeline
from openai import OpenAI
client = OpenAI()
import os
from dotenv import load_dotenv

# Load environment variables from the .env file
load_dotenv()

# Set your OpenAI API key
client.api_key = os.getenv("OPENAI_API_KEY")

class EntityExtractor:
    def __init__(self, model_name="Clinical-AI-Apollo/Medical-NER", aggregation_strategy='simple', use_gpt=False, openai_api_key=None):
        """
        Initialize the EntityExtractor with a specific model.

        Args:
            model_name (str): The name of the model to use for the pipeline.
            aggregation_strategy (str): The strategy to use for aggregation.
            use_gpt (bool): Whether to use GPT-3.5 for entity extraction.
            openai_api_key (str): The OpenAI API key to use for GPT-3.5.
        """
        self.use_gpt = use_gpt
        if use_gpt:
            if not openai_api_key:
                raise ValueError("OpenAI API key must be provided if using GPT-3.5")
            client.api_key = openai_api_key
        else:
            self.pipe = hf_pipeline("token-classification", model=model_name, aggregation_strategy=aggregation_strategy)

    def extract_specific_entities(self, text, target_entities=['DISEASE_DISORDER', 'MEDICATION']):
        """
        Extract specific entities from the given text using the initialized pipeline or GPT-3.5.

        Args:
            text (str): The input text from which to extract entities.
            target_entities (list): List of entity types to extract (default is ['DISEASE_DISORDER', 'MEDICATION']).

        Returns:
            dict: A dictionary with the highest-scoring extracted entity for each target type or an empty string if none.
        """
        if self.use_gpt:
            return self.extract_with_gpt(text, target_entities)
        else:
            return self.extract_with_model(text, target_entities)

    def extract_with_model(self, text, target_entities):
        results = self.pipe(text)
        extracted_entities = {'diseases': '', 'medications': ''}
        entity_mapping = {
            'DISEASE_DISORDER': 'diseases',
            'MEDICATION': 'medications'
        }
        highest_score_entities = {key: {'score': 0, 'entity': ''} for key in entity_mapping.values()}
        
        for entity in results:
            entity_type = entity['entity_group']
            if entity_type in target_entities:
                key = entity_mapping[entity_type]
                if entity['score'] > highest_score_entities[key]['score']:
                    highest_score_entities[key] = {'score': entity['score'], 'entity': entity['word']}
        
        for key, value in highest_score_entities.items():
            extracted_entities[key] = value['entity']
        
        return extracted_entities

    def extract_with_gpt(self, text, target_entities):
        messages = [
            {"role": "user", "content": f"Extract the following entities from the text: {', '.join(target_entities)} and output those entities as a JSON object with this format {{'diseases': [], 'medications': []}}. Text: {text}"}
        ]
        
        response = client.chat.completions.create(
            model="gpt-3.5-turbo-16k",
            messages=messages,
            temperature=1,
            max_tokens=512,
            top_p=1,
            frequency_penalty=0,
            presence_penalty=0
        )
        
        extracted_entities = {'diseases': '', 'medications': ''}
        
        try:
            # Ensure correct parsing of the response content
            response_content = response.choices[0].message.content.strip()
            # Assuming the response is directly a dictionary in string form
            extracted_entities = eval(response_content.split('\n')[0])
        except Exception as e:
            print(f"Error parsing GPT response: {e}")
        
        return extracted_entities

# Example usage
if __name__ == "__main__":
    # Load OpenAI API key from environment variable
    openai_api_key = os.getenv("OPENAI_API_KEY")
    
    # Initialize with GPT-3.5
    gpt_extractor = EntityExtractor(use_gpt=True, openai_api_key=openai_api_key)
    text = "45 year old woman diagnosed with CAD and hypertension, prescribed with aspirin and paracetamol."
    gpt_extracted_entities = gpt_extractor.extract_specific_entities(text)
    print(gpt_extracted_entities)  # Output should be the parsed dictionary
# Out:
# {'diseases': ['CAD', 'hypertension'], 'medications': ['aspirin', 'paracetamol']}

# %%
from openai import OpenAI
client = OpenAI()
import os
from dotenv import load_dotenv

target_entities = ['diseases','medications']
text = "45 year old woman diagnosed with CAD and hypertension, prescribed with aspirin and paracetamol."
messages = [
            {"role": "user", "content": f"Extract the following entities from the text: {', '.join(target_entities)} and output those entities as a JSON object with this format {{'diseases': [], 'medications': []}}. Text: {text}"}
]

response = client.chat.completions.create(
  model="gpt-3.5-turbo-16k",
  messages=messages,
  temperature=1,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

# %%
response
# Out:
# ChatCompletion(id='chatcmpl-9YHcYK229UEgm7RJ8JCNgOTsQcBVm', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="{'diseases': ['CAD', 'hypertension'], 'medications': ['aspirin', 'paracetamol']}", role='assistant', function_call=None, tool_calls=None))], created=1717957914, model='gpt-3.5-turbo-16k-0613', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=29, prompt_tokens=65, total_tokens=94))

# %%
response.choices[0].message.content.strip().split('\n')[0]
# Out:
# "{'diseases': ['CAD', 'hypertension'], 'medications': ['aspirin', 'paracetamol']}"

# %%
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[27], line 17
#      12 text = "45 year old woman diagnosed with CAD and hypertension, prescribed with aspirin and paracetamol."
#      13 messages = [
#      14     {"role": "user", "content": f"Extract the following entities from the text: {', '.join(target_entities)} and output those entities as dictionary with this format {{'diseases' : [], 'medications': []}}. Text: {text}"}
#      15 ]
# ---> 17 response = openai.ChatCompletion.create(
#      18     model="gpt-3.5-turbo-16k",
#      19     messages=messages,
#      20     temperature=1,
#      21     max_tokens=512,
#      22     top_p=1,
#      23     frequency_penalty=0,
#      24     presence_penalty=0
#      25 )
#      27 print(response)
#      29 # Extract and parse the response content
#
# File ~/dbt-dlt/lib/python3.10/site-packages/openai/lib/_old_api.py:39, in APIRemovedInV1Proxy.__call__(self, *_args, **_kwargs)
#      38 def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ---> 39     raise APIRemovedInV1(symbol=self._symbol)
#
# APIRemovedInV1:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
